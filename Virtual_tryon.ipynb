# %%
# Out:
# GPU is not available.

# %%
pip install opencv-python torchgeometry
# Out:
# Requirement already satisfied: opencv-python in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (4.10.0.84)
# Requirement already satisfied: torchgeometry in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (0.1.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: torch>=1.0.0 in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (from torchgeometry) (1.6.0)
# Requirement already satisfied: future in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (from torch>=1.0.0->torchgeometry) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !nvidia-smi
# Out:
# Wed Oct 16 00:46:28 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 556.13                 Driver Version: 556.13         CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   57C    P0             12W /   60W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
pip uninstall torch torchvision torchaudio
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu125
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu125Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: torch in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (1.6.0)
# Requirement already satisfied: torchvision in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (0.7.0)
# Requirement already satisfied: torchaudio in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (0.6.0)
# Requirement already satisfied: future in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (from torch) (1.0.0)
# Requirement already satisfied: numpy in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (from torch) (1.24.3)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\91701\anaconda3\envs\virtual_tryon\lib\site-packages (from torchvision) (10.4.0)

# %%
import torch

if torch.cuda.is_available():
    print("GPU is available. GPU ID: 0")
    print("GPU Name:", torch.cuda.get_device_name(0))
else:
    print("GPU is not available.")
# Out:
# GPU is not available.

# %%
which python
# Out:
#   Cell In[3], line 1
#     which python
#           ^
# SyntaxError: invalid syntax
